# %% [markdown]
# # 🚀 RLAIF Training on Google Colab (T4 GPU)
#
# This notebook allows you to run the RLAIF training pipeline on a free Google Colab T4 GPU instance.
#
# **Pre-requisites:**
# 1.  HuggingFace Token (Read access)
# 2.  WandB API Key (for logging)

# %%
# 1. Install Dependencies
# !pip install -q git+https://github.com/huggingface/trl.git
# !pip install -q git+https://github.com/huggingface/peft.git
# !pip install -q transformers datasets accelerate bitsandbytes wandb

# %%
# 2. Clone Repository
# !git clone https://github.com/Vedang1308/RLAIF.git
# %cd RLAIF
# !git pull

# %%
# 3. Authenticate
import os
from google.colab import userdata

# Ideally set these in Colab Secrets (Key icon on left)
# Or uncomment below to input manually:
# os.environ["WANDB_API_KEY"] = input("WandB Key: ")
# os.environ["HF_TOKEN"] = input("HF Token: ")

# %%
# 4. Run Training (Demo Mode)
# We run directly with python. 
# T4 GPU has ~16GB VRAM. We might need 4-bit loading.
# We will modify train.py arguments slightly or rely on the script's robustness.

# !python train.py --mode demo --total_steps 50

# %% [markdown]
# ### 📊 Visualizing Results
# Since Streamlit is hard to view in Colab without tunneling (ngrok), we recommend monitoring progress via the **WandB link** printed in the output above.
